# %% [markdown]
# House price prediction kaggle competition

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#loading train.csv file
train = pd.read_csv('/content/drive/My Drive/house price prediction/train.csv')

# %% [markdown]
# Basic dataframe info

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
#ploting heatmap on basis of missing values
plt.figure(figsize=(16,9))
sns.heatmap(train.isnull(), yticklabels=False, cbar=False)
plt.show()

# %% [markdown]
# steps to solve problem:
#
#
#
# *   Data clening and preprocessing
# *   EDA
# *   Feature engineering
# *   Feature selection
# *   ML modeling

# %% [markdown]
# Data cleanig and preprocessing

# %%
cols = []
for (col_name, col_data) in train.iteritems():
  if col_name != 'Id':
    if col_name != 'SalePrice': 
     cols.append(col_name)

# %%
#check for duplicate datapoints
duplicate_rows = train[train.duplicated(subset = cols)]

# %%
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %% [markdown]
# EDA
#
# *   missing values
# *   all numerical variables
# *   distribution of numerical variables
# *   categorical variables
# *   cardinality of variables
# *   outliers
# *   relation between independent and dependent variables

# %% [markdown]
# Missing values

# %%
features_with_nan = []
for feature in train.columns:
  if train[feature].isnull().sum()>1:
    features_with_nan.append(feature)
    print(feature, np.round(train[feature].isnull().mean()*100, 4), '% missing values')
# Out:
# LotFrontage 17.7397 % missing values
# Alley 93.7671 % missing values
# MasVnrType 0.5479 % missing values
# MasVnrArea 0.5479 % missing values
# BsmtQual 2.5342 % missing values
# BsmtCond 2.5342 % missing values
# BsmtExposure 2.6027 % missing values
# BsmtFinType1 2.5342 % missing values
# BsmtFinType2 2.6027 % missing values
# FireplaceQu 47.2603 % missing values
# GarageType 5.5479 % missing values
# GarageYrBlt 5.5479 % missing values
# GarageFinish 5.5479 % missing values
# GarageQual 5.5479 % missing values
# GarageCond 5.5479 % missing values
# PoolQC 99.5205 % missing values
# Fence 80.7534 % missing values
# MiscFeature 96.3014 % missing values

# %%
#relation between missing values and dependent feature(salesprice)
for feature in features_with_nan:
    data = train.copy()
    
    # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    # let's calculate the mean SalePrice where the information is missing or present
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# from above relations missing values and sales price are related.so we need to replace nan values with some meaningful information.

# %% [markdown]
# Numerical variables

# %%
#all numerical variables
numerical_features = []
for feature in train.columns:
  if train[feature].dtype != 'O':
    numerical_features.append(feature)
numerical_features
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
print('number of numerical features', len(numerical_features))
data[numerical_features].head()
# Out:
# number of numerical features 38
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008     208500
# 1   2          20         80.0     9600  ...        0       5    2007     181500
# 2   3          60         68.0    11250  ...        0       9    2008     223500
# 3   4          70         60.0     9550  ...        0       2    2006     140000
# 4   5          60         84.0    14260  ...        0      12    2008     250000
#
# [5 rows x 38 columns]

# %% [markdown]
# Temporal variables(datatime variables)

# %%
year_feature = []
for feature in train.columns:
  if ('Year' in feature) or ('Yr' in feature):
    year_feature.append(feature)
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for year in year_feature:
  print(year, train[year].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
#scatter plot
for year in year_feature:
  data = train.copy()
  data[year] = data['YrSold']-data[year]
  plt.scatter(data[year], data['SalePrice'])
  plt.xlabel(year)
  plt.ylabel('saleprice')
  plt.show()

# %%
data.groupby('YrSold')['SalePrice'].median().plot()
plt.show()

# %%
#discrete features
discrete_feature = []
for feature in numerical_features:
  if (len(data[feature].unique())<25) and (feature not in year_feature+['Id']):
    discrete_feature.append(feature)

# %%
print(len(discrete_feature))
# Out:
# 17

# %%
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
train[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  ...  PoolArea  MiscVal  MoSold
# 0          60            7            5  ...         0        0       2
# 1          20            6            8  ...         0        0       5
# 2          60            7            5  ...         0        0       9
# 3          70            7            5  ...         0        0       2
# 4          60            8            5  ...         0        0      12
#
# [5 rows x 17 columns]

# %%
#relation between discrete feature and saleprice
for feature in discrete_feature:
  data = train.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.show()

# %% [markdown]
# Countinous features

# %%
#coutinous features
coutinous_feature = [feature for feature in numerical_features if feature not in discrete_feature+year_feature+['Id']]
print(len(coutinous_feature))
# Out:
# 16

# %%
coutinous_feature
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
data[coutinous_feature].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  ...  EnclosedPorch  ScreenPorch  SalePrice
# 0         65.0     8450       196.0  ...              0            0     208500
# 1         80.0     9600         0.0  ...              0            0     181500
# 2         68.0    11250       162.0  ...              0            0     223500
# 3         60.0     9550         0.0  ...            272            0     140000
# 4         84.0    14260       350.0  ...              0            0     250000
#
# [5 rows x 16 columns]

# %%
#distribution of countinous features
for feature in coutinous_feature:
  plt.hist(data[feature], bins=25)
  plt.xlabel(feature)
  plt.show()

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
#logarithmic transformation to countinous features
for feature in coutinous_feature:
  data = train.copy()
  if 0 in data[feature].unique():
    pass
  else:
      data[feature] = np.log(data[feature])
      plt.hist(data[feature], bins=25)
      plt.xlabel(feature)
      plt.show()

# %%
#scatter plot between sales price and countinous features
for feature in coutinous_feature:
  data = train.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])  
    data["SalePrice"] = np.log(data['SalePrice'])
    plt.scatter(data[feature], data['SalePrice'])
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# Outliers

# %%
#outliers
for feature in coutinous_feature:
  data = train.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    sns.boxplot(y = data[feature])
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# Categorical features

# %%
categorical_feature = [feature for feature in data.columns if data[feature].dtype == 'O']
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
data[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape  ... Fence MiscFeature SaleType SaleCondition
# 0       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 1       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 2       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
# 3       RL   Pave   NaN      IR1  ...   NaN         NaN       WD       Abnorml
# 4       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
#no. of categories in each of categorical features
for feature in categorical_feature:
  print(feature, '->', len(data[feature].unique()))
# Out:
# MSZoning -> 5
# Street -> 2
# Alley -> 3
# LotShape -> 4
# LandContour -> 4
# Utilities -> 2
# LotConfig -> 5
# LandSlope -> 3
# Neighborhood -> 25
# Condition1 -> 9
# Condition2 -> 8
# BldgType -> 5
# HouseStyle -> 8
# RoofStyle -> 6
# RoofMatl -> 8
# Exterior1st -> 15
# Exterior2nd -> 16
# MasVnrType -> 5
# ExterQual -> 4
# ExterCond -> 5
# Foundation -> 6
# BsmtQual -> 5
# BsmtCond -> 5
# BsmtExposure -> 5
# BsmtFinType1 -> 7
# BsmtFinType2 -> 7
# Heating -> 6
# HeatingQC -> 5
# CentralAir -> 2
# Electrical -> 6
# KitchenQual -> 4
# Functional -> 7
# FireplaceQu -> 6
# GarageType -> 7
# GarageFinish -> 4
# GarageQual -> 6
# GarageCond -> 6
# PavedDrive -> 3
# PoolQC -> 4
# Fence -> 5
# MiscFeature -> 5
# SaleType -> 9
# SaleCondition -> 6

# %%
#relation between categorical feature and sales price
for feature in categorical_feature:
  data = train.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.show()

# %% [markdown]
# Feature engineering

# %%
#split train test split in train data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train, train['SalePrice'], test_size = 0.1, random_state=0)
print('train', x_train.shape, 'test', x_test.shape)
# Out:
# train (1314, 81) test (146, 81)

# %% [markdown]
# handling missing values

# %%
#missing values in categorical features
missing_cat_feature = []
for feature in categorical_feature:
  data = train.copy()
  if data[feature].isnull().sum()>1:
    missing_cat_feature.append(feature)
    print(feature, '->', data[feature].isnull().mean()*100, '% missing values')
# Out:
# Alley -> 93.76712328767123 % missing values
# MasVnrType -> 0.547945205479452 % missing values
# BsmtQual -> 2.5342465753424657 % missing values
# BsmtCond -> 2.5342465753424657 % missing values
# BsmtExposure -> 2.6027397260273974 % missing values
# BsmtFinType1 -> 2.5342465753424657 % missing values
# BsmtFinType2 -> 2.6027397260273974 % missing values
# FireplaceQu -> 47.26027397260274 % missing values
# GarageType -> 5.5479452054794525 % missing values
# GarageFinish -> 5.5479452054794525 % missing values
# GarageQual -> 5.5479452054794525 % missing values
# GarageCond -> 5.5479452054794525 % missing values
# PoolQC -> 99.52054794520548 % missing values
# Fence -> 80.75342465753424 % missing values
# MiscFeature -> 96.30136986301369 % missing values

# %%
missing_cat_feature
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
#function to replace missing values(nan) with 'missing'
def fill_cat_nan(dataset, missing_cols):
  data = dataset.copy()
  data[missing_cols] = data[missing_cols].fillna('Missing')
  return data
train = fill_cat_nan(train, missing_cat_feature)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
train[missing_cat_feature].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
#numerical features with missing values
missing_num_feature = [feature for feature in numerical_features if data[feature].isnull().sum()>1]
missing_num_feature
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
#replace nan values with mean and create new feature feature_nan
for feature in missing_num_feature:
  median_vals = train[feature].median()
  train[feature+'nan'] = np.where(train[feature].isnull(), 1,0)#create new feature to capture nan value
  train[feature].fillna(median_vals, inplace=True)#replace nan value with median

# %%
train[missing_num_feature].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0   1          60       RL  ...               0              0              0
# 1   2          20       RL  ...               0              0              0
# 2   3          60       RL  ...               0              0              0
# 3   4          70       RL  ...               0              0              0
# 4   5          60       RL  ...               0              0              0
#
# [5 rows x 84 columns]

# %%
#temporal variables
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
  train[feature] = train['YrSold']-train[feature]

# %%
train[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
coutinous_feature
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
#performing logarithmic trasformation to countinous features
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    train[feature]=np.log(train[feature])

# %%
#replace rare categories of feature with rare_vals
categorical_feature = [feature for feature in train.columns if train[feature].dtype == 'O']
for feature in categorical_feature:
    temp=train.groupby(feature)['SalePrice'].count()/len(train)
    temp_df=temp[temp>0.01].index
    train[feature]=np.where(train[feature].isin(temp_df),train[feature],'Rare_var')

# %%
train[categorical_feature].head()
# Out:
#   MSZoning Street    Alley LotShape  ...    Fence MiscFeature SaleType SaleCondition
# 0       RL   Pave  Missing      Reg  ...  Missing     Missing       WD        Normal
# 1       RL   Pave  Missing      Reg  ...  Missing     Missing       WD        Normal
# 2       RL   Pave  Missing      IR1  ...  Missing     Missing       WD        Normal
# 3       RL   Pave  Missing      IR1  ...  Missing     Missing       WD       Abnorml
# 4       RL   Pave  Missing      IR1  ...  Missing     Missing       WD        Normal
#
# [5 rows x 43 columns]

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0   1          60       RL  ...               0              0              0
# 1   2          20       RL  ...               0              0              0
# 2   3          60       RL  ...               0              0              0
# 3   4          70       RL  ...               0              0              0
# 4   5          60       RL  ...               0              0              0
#
# [5 rows x 84 columns]

# %%
#converting categorical variables to numerical variables
for feature in categorical_feature:
    labels_ordered=train.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    train[feature]=train[feature].map(labels_ordered)

# %%
train.head()
# Out:
#    Id  MSSubClass  MSZoning  ...  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1          60         3  ...               0              0               0
# 1   2          20         3  ...               0              0               0
# 2   3          60         3  ...               0              0               0
# 3   4          70         3  ...               0              0               0
# 4   5          60         3  ...               0              0               0
#
# [5 rows x 84 columns]

# %% [markdown]
# Feature scaling

# %%
feature_scale = [feature for feature in train.columns if feature not in ['Id', 'SalePrice']]
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
scale.fit(train[feature_scale])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
#creating new dataframe after concat id sales and fit data
dataset = pd.concat([train[['Id', 'SalePrice']].reset_index(drop=True),pd.DataFrame(scale.transform(train[feature_scale]), columns=feature_scale)],axis=1)

# %%
dataset.head()
# Out:
#    Id  SalePrice  MSSubClass  ...  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1  12.247694    0.235294  ...             0.0            0.0             0.0
# 1   2  12.109011    0.000000  ...             0.0            0.0             0.0
# 2   3  12.317167    0.235294  ...             0.0            0.0             0.0
# 3   4  11.849398    0.294118  ...             0.0            0.0             0.0
# 4   5  12.429216    0.235294  ...             0.0            0.0             0.0
#
# [5 rows x 84 columns]

# %% [markdown]
# Feature selection

# %%
#separating id and salesprice
label = dataset['SalePrice']
data = dataset.drop(['SalePrice', 'Id'], axis=1)

# %%
data.shape
# Out:
# (1460, 82)

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  ...  MasVnrAreanan  GarageYrBltnan
# 0    0.235294      0.75  ...            0.0             0.0
# 1    0.000000      0.75  ...            0.0             0.0
# 2    0.235294      0.75  ...            0.0             0.0
# 3    0.294118      0.75  ...            0.0             0.0
# 4    0.235294      0.75  ...            0.0             0.0
#
# [5 rows x 82 columns]

# %%
#now selecting important features only using l1 regularization of linear regression
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
model = SelectFromModel(Lasso(alpha=0.005, random_state=0))
model.fit(data, label)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
 model.get_support()
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False])

# %%
imp_features = data.columns[model.get_support()]
print('important features:')
print(imp_features)
print('no of important features:', len(imp_features))
print('total no of features', len(data.columns))
# Out:
# important features:
# Index(['MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual', 'YearRemodAdd',
#        'RoofStyle', 'BsmtQual', 'BsmtExposure', 'HeatingQC', 'CentralAir',
#        '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'KitchenQual', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'PavedDrive',
#        'SaleCondition'],
#       dtype='object')
# no of important features: 21
# total no of features 82

# %%
data = data[imp_features]
print(data.shape)
data.head()
# Out:
# (1460, 21)
#    MSSubClass  MSZoning  Neighborhood  ...  GarageCars  PavedDrive  SaleCondition
# 0    0.235294      0.75      0.636364  ...        0.50         1.0           0.75
# 1    0.000000      0.75      0.500000  ...        0.50         1.0           0.75
# 2    0.235294      0.75      0.636364  ...        0.50         1.0           0.75
# 3    0.294118      0.75      0.727273  ...        0.75         1.0           0.00
# 4    0.235294      0.75      1.000000  ...        0.75         1.0           0.75
#
# [5 rows x 21 columns]

# %%
#now creating new dataframe 
data['SalePrice'] = label
clean_df = data.copy()
clean_df.to_csv('clean_df.csv')
#saving cleaned dataset
from google.colab import files
files.download("clean_df.csv")

# %% [markdown]
# Machine learnig models

# %%
data = pd.read_csv('/content/drive/My Drive/house price prediction/clean_df.csv')
data.shape
# Out:
# (1460, 23)

# %%
data.head()
# Out:
#    Unnamed: 0  MSSubClass  MSZoning  ...  PavedDrive  SaleCondition  SalePrice
# 0           0    0.235294      0.75  ...         1.0           0.75  12.247694
# 1           1    0.000000      0.75  ...         1.0           0.75  12.109011
# 2           2    0.235294      0.75  ...         1.0           0.75  12.317167
# 3           3    0.294118      0.75  ...         1.0           0.00  11.849398
# 4           4    0.235294      0.75  ...         1.0           0.75  12.429216
#
# [5 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual',
#        'YearRemodAdd', 'RoofStyle', 'BsmtQual', 'BsmtExposure', 'HeatingQC',
#        'CentralAir', '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'KitchenQual',
#        'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars',
#        'PavedDrive', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
label = data['SalePrice']
features = data.drop(['Unnamed: 0', 'SalePrice'], axis=1)
features.shape
# Out:
# (1460, 21)

# %%
#train test and split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, label, random_state=0, test_size=0.2)
print('x_train:', x_train.shape)
print('x_test:', x_test.shape)
# Out:
# x_train: (1168, 21)
# x_test: (292, 21)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lgn = LinearRegression()
lgn.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted = lgn.predict(x_test)

# %%
#performace of model
from sklearn.metrics import r2_score, mean_squared_error
print('rsquared error:', r2_score(predicted, y_test))
print('mean squared error:', mean_squared_error(predicted, y_test))
print('root squared error:', np.sqrt(mean_squared_error(predicted, y_test)))
# Out:
# rsquared error: 0.848768842070903
# mean squared error: 0.023770030441097007
# root squared error: 0.1541753237100445

# %% [markdown]
# xgboost

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
xgr = XGBRegressor()

# %%
#hyper parameter optimization for randomizesearch
base_score=[0.25,0.5,0.75,1]
n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
random_cv = RandomizedSearchCV(estimator=xgr,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 250 out of 250 | elapsed:  1.7min finished
# [19:50:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1, gamma=0,
#                                           importance_type='gain',
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=2, min_child_weight=4, missing=None, n_estimators=900,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
regressor = XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0,
             importance_type='gain', learning_rate=0.05, max_delta_step=0,
             max_depth=2, min_child_weight=4, missing=None, n_estimators=900,
             n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
             silent=None, subsample=1, verbosity=1)

# %%
regressor.fit(x_train, y_train)
# Out:
# [19:53:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=2, min_child_weight=4, missing=None, n_estimators=900,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predicted = regressor.predict(x_test)

# %%
#performence metrics
print('rsquared error:', r2_score(predicted, y_test))
print('mean squared error:', mean_squared_error(predicted, y_test))
print('root squared error:', np.sqrt(mean_squared_error(predicted, y_test)))
# Out:
# rsquared error: 0.8874508008703965
# mean squared error: 0.017456352473625897
# root squared error: 0.13212249041562113

# %% [markdown]
# conclusion: between simple linear regression and xgboost regression xgboost regressor performce better.
